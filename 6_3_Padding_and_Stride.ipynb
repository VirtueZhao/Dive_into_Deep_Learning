# %% [markdown]
# <a href="https://colab.research.google.com/github/VirtueZhao/Dive_into_Deep_Learning/blob/main/6_3_Padding_and_Stride.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn

def comp_conv2d(conv2d, X):
  # print("X Before Padding: ", X)
  # print(X.shape)
  X = X.reshape((1,1) + X.shape)
  # print(X.shape)
  # print("X after Padding: ", X)
  Y = conv2d(X)
  return Y.reshape(Y.shape[2:])

conv2d = nn.Conv2d(1,1,kernel_size=3,padding=1)
print(conv2d)
X = torch.rand(size=(8,8))
comp_conv2d(conv2d, X).shape
# Out:
# Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# torch.Size([8, 8])

# %%
conv2d = nn.Conv2d(1,1,kernel_size=(5,3), padding=(2,1))
comp_conv2d(conv2d, X).shape
# Out:
# torch.Size([8, 8])

# %%
conv2d = nn.Conv2d(1,1,kernel_size=3, padding=1, stride=2)
comp_conv2d(conv2d, X).shape
# Out:
# torch.Size([4, 4])

# %%
conv2d = nn.Conv2d(1,1,kernel_size=(3,5), padding=(0,1), stride=(3,4))
comp_conv2d(conv2d, X).shape
# Out:
# torch.Size([2, 2])

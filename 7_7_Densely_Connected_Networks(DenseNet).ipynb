# %% [markdown]
# <a href="https://colab.research.google.com/github/VirtueZhao/Dive_into_Deep_Learning/blob/main/7_7_Densely_Connected_Networks(DenseNet).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import d2l
import torch
from torch import nn

# %%
def conv_block(input_channels, num_channels):
  return nn.Sequential(
      nn.BatchNorm2d(input_channels), nn.ReLU(),
      nn.Conv2d(input_channels, num_channels, kernel_size=3, padding=1))

# %%
class DenseBlock(nn.Module):
  def __init__(self, num_convs, input_channels, num_channels):
    super(DenseBlock, self).__init__()
    layer = []
    for i in range(num_convs):
      layer.append(conv_block(num_channels * i + input_channels, num_channels))
    print(layer)
    self.net = nn.Sequential(*layer)
  
  def forward(self, X):
    for blk in self.net:
      print(X.shape)
      Y = blk(X)
      print(Y.shape)
      X = torch.cat((X, Y), dim=1)
      print(X.shape)
      print()
    return X

blk = DenseBlock(2, 3, 10)
X = torch.randn(4, 3, 8, 8)
Y = blk(X)
Y.shape
# Out:
# [Sequential(
#   (0): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (1): ReLU()
#   (2): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ), Sequential(
#   (0): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (1): ReLU()
#   (2): Conv2d(13, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )]
# torch.Size([4, 3, 8, 8])
# torch.Size([4, 10, 8, 8])
# torch.Size([4, 13, 8, 8])
#
# torch.Size([4, 13, 8, 8])
# torch.Size([4, 10, 8, 8])
# torch.Size([4, 23, 8, 8])
# torch.Size([4, 23, 8, 8])

# %%
blk = DenseBlock(2, 3, 10)
X = torch.randn(4, 3, 8, 8)
Y = blk(X)
Y.shape
# Out:
# [Sequential(
#   (0): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (1): ReLU()
#   (2): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ), Sequential(
#   (0): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (1): ReLU()
#   (2): Conv2d(13, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )]
# torch.Size([4, 3, 8, 8])
# torch.Size([4, 10, 8, 8])
# torch.Size([4, 13, 8, 8])
#
# torch.Size([4, 13, 8, 8])
# torch.Size([4, 10, 8, 8])
# torch.Size([4, 23, 8, 8])
# torch.Size([4, 23, 8, 8])

# %%
def transition_block(input_channels, num_channels):
  return nn.Sequential(
      nn.BatchNorm2d(input_channels), nn.ReLU(),
      nn.Conv2d(input_channels, num_channels, kernel_size=1),
      nn.AvgPool2d(kernel_size=2, stride=2)
  )

blk = transition_block(23, 10)
blk(Y).shape
# Out:
# torch.Size([4, 10, 4, 4])

# %%
b1 = nn.Sequential(
    nn.
)
